# %%
import pandas as pd

# %%
df=pd.read_csv("basketball.csv")

# %%
pd.read_csv("basketball.csv",skiprows=[1,2,3])
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 1      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# 2      5   Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21
# 3      5   Arron Afflalo  SG  29  POR  25  19   752   94  227  ...  .851    6
# 4      6   Alexis Ajinça   C  26  NOP  68   8   957  181  329  ...  .818  104
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 667  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 668  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 669  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 670  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 671  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Rk         Player Pos Age   Tm   G  GS    MP   FG  ...   FT%  \
# 0           0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  ...  .784
# 1           1  2   Jordan Adams  SG  20  MEM  30   0   248   35  ...  .609
# 2           2  3   Steven Adams   C  21  OKC  70  67  1771  217  ...  .502
# 3           3  4    Jeff Adrien  PF  28  MIN  17   0   215   19  ...  .579
# 4           4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  ...  .843
#
#    ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0   79  222  301   68  27  22   60  147   398
# 1    9   19   28   16  16   7   14   24    94
# 2  199  324  523   66  38  86   99  222   537
# 3   23   54   77   15   4   9    9   30    60
# 4   27  220  247  129  41   7  116  167  1035
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df.to_csv("basketballresult1.csv",index=False,sep="@",columns=["Player","Pos"])

# %%
df.tail(10)
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 665         665  485  Brandan Wright  PF  27  PHO  40   7   858  120  ...
# 666         666  486   Dorell Wright  SF  29  POR  48   2   592   72  ...
# 667         667  487     Tony Wroten  PG  21  PHI  30  15   895  175  ...
# 668         668  488     James Young  SG  19  BOS  31   0   332   36  ...
# 669         669  489      Nick Young  SG  29  LAL  42   0  1000  174  ...
# 670         670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  ...
# 671         671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  ...
# 672         672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  ...
# 673         673  491     Cody Zeller   C  22  CHO  62  45  1487  172  ...
# 674         674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  ...
#
#       FT%  ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 665  .667   70  124  194   23   32  47   16   54   280
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a=df["Player"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG',
#        'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'],
#       dtype='object')

# %%
df.to_xml()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4668/226467173.py in <module>
# ----> 1 df.to_xml()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_xml(self, path_or_buffer, index, root_name, row_name, na_rep, attr_cols, elem_cols, namespaces, prefix, encoding, xml_declaration, pretty_print, parser, stylesheet, compression, storage_options)
#    2984         )
#    2985
# -> 2986         return xml_formatter.write_output()
#    2987
#    2988     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\xml.py in write_output(self)
#     263
#     264     def write_output(self) -> str | None:
# --> 265         xml_doc = self.build_tree()
#     266
#     267         out_str: str | None
#
# ...

# %%
pd.read_csv("basketballresult1.csv",sep="@")
# Out:
#              Player Pos
# 0        Quincy Acy  PF
# 1      Jordan Adams  SG
# 2      Steven Adams   C
# 3       Jeff Adrien  PF
# 4     Arron Afflalo  SG
# ..              ...  ..
# 670  Thaddeus Young  PF
# 671  Thaddeus Young  PF
# 672  Thaddeus Young  PF
# 673     Cody Zeller   C
# 674    Tyler Zeller   C
#
# [675 rows x 2 columns]

# %%
df=pd.read_csv("basketball.csv")

# %%
df
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
type(df["Player"])
# Out:
# pandas.core.series.Series

# %%
type(df[["Player"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Player","Pos"]]
# Out:
#              Player Pos
# 0        Quincy Acy  PF
# 1      Jordan Adams  SG
# 2      Steven Adams   C
# 3       Jeff Adrien  PF
# 4     Arron Afflalo  SG
# ..              ...  ..
# 670  Thaddeus Young  PF
# 671  Thaddeus Young  PF
# 672  Thaddeus Young  PF
# 673     Cody Zeller   C
# 674    Tyler Zeller   C
#
# [675 rows x 2 columns]

# %%
df2=pd.read_excel("lusidbusiness.xlsx",sheet_name="Create your instrument universe")

# %%
df4=pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html")

# %%
type(df4)
# Out:
# list

# %%
df4[3].to_csv("players_data.csv")

# %%
type(pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html"))
# Out:
# list

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s="""{
"name" : "nishit",
"phone_no" : "1245151515",
"company" : ["ineuron","unilver","verizon","Deloitte","wipro"]
}
"""

# %%
import json

# %%
s1=json.loads(s)

# %%
pd.DataFrame(s1,columns=["company"])
# Out:
#     company
# 0   ineuron
# 1   unilver
# 2   verizon
# 3  Deloitte
# 4     wipro

# %%
import requests

# %%
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
js=res.json()

# %%
pd.DataFrame(js).to_csv("jsondata.csv")
